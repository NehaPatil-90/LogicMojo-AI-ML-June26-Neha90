# %%
x= 8

print(f"Value of x : {x}, Type : {type(x)}")
# Out:
# Value of x : 8, Type : <class 'int'>

# %%
x= 3.14
print(x)
print(type(x))
# Out:
# 3.14
# <class 'float'>

# %%
x= 12
y= 10

print(f"Binary value of {x} is : {bin(x)}")
print(f"Binary value of {y} is : {bin(y)}")
print(f"AND : {x & y}")
print(f"OR {x | y}")
print(f"XOR {x ^ y}")
# Out:
# Binary value of 12 is : 0b1100
# Binary value of 10 is : 0b1010
# AND : 8
# OR 14
# XOR 6

# %%
x= 10
print(f"Int {x} to float {float(x)}")
# Out:
# Int 10 to float 10.0
